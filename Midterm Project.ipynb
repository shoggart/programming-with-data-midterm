# %% [markdown]
# Introduction:
# The objective of this independent research project is to analyze rates of COVID in Washington state by number of deaths, hospitalizations and positive tests over the course of a year spanning from March 1, 2020 to March 1, 2021 using Python in a Jupyter notebook and while utilizing various packages from the course such as Pandas, NumPy, etc... Various metrics will be used to analyze these data including cumulative cases as well as rates per day. The dataset I will be mainly working with comes from The COVID Tracking Project at The Atlantic Magazine.

# %% [markdown]
# Relevancy:
# As mentioned above, the origin of our data for this research project comes from the COVID Tracking Project at The Atlantic. The data source is a CSV file containing numerous metrics pertaining to COVID statistics in Washington state. It covers everything from the obvious statistics such as total deaths and hospitalizations to more meticulous data such as ventilator statistics and positive antibody or positive antigen tests. This is a highly appropriate data source for our research project for various reasons; the main one being it contained an extensive number of metrics from which to analyze. This should be evident from the sizable number of columns and rows deleted from the dataset below using Pandas.

# %% [markdown]
# Background:
# This field of inquiry is definitely of high value. COVID-19 essentially dictated the world for almost all of 2020. People have been very antsy to get back to some semblance of normalcy for quite some time now. There are few things I can think of that should be prioritized higher than when the world can safely start to reopen and people can resume there lives. The one thing about this topic that is perhaps one of its downfalls is that it has been very highly researched over the last year and a half. Literally, the entire world has been looking at these statistics and trying to draw conclusions from them since the beginning of 2020. That being said,

# %% [markdown]
# Dataset Exploration:
# Illegal values such as NaN have been removed from the original dataset. Also, extensive time has been spent condensing the data set down to a 1 year time frame extending from March 1, 2020 to February 28, 2021. And that doesn't even mention the number of columns of data that needed to be removed to be left with a reasonable dataset. For the purpose of this project, I've decided to analyze this data set in the form of a Pandas data frame. The dataset has been modified where appropriate for whichever form of analysis is applicable. For example, in the beginning many columns and rows have been deleted for the sake of data manipulation. And at other times row indices have been reinitialized for the purpose of clarity of information. I've implemented a scatterplot to see how deaths per day measure up to the average over the course of a year during peak intervals of COVID-19 rates.

# %% [markdown]
# Ethics:
# As stated earlier, the data came from the COVID Tracking Project at The Atlantic. This was an open source dataset that was free to download. The analysis of this data doesn't run the risk of creating new forms of intellectual property, by definition. Intellectual property is an invention of some sort that one has the rights to but there's no software or anything tangible to be gained from this analysis. However, there is a risk of discrimination in this analysis. COVID appears to have disproportionately affected poor people and different races which this analysis is not taking into consideration. The data only reports information about the entire state of Washington which could potentially underrepresent some demographics. I think this could create harmful assumptions if different communities are being affected disproportionately. For example, if the general trend of COVID cases in Washington state is going down people may feel more entitled to be more lax about social distancing and mask wearing. For instance, if the total number of cases is going down but cases are increasing in certain communities or demographics this could have dangerous repercussions for those communities. On a more positive note, this data is fully anonymous. It is purely statistical in nature and the manipulations on the data can be clearly identified. As far as biases are concerned, there is the possibility of bias that was mentioned earlier. For example, according to the Washington state Office of Finanicial Management, 78.7% of the total population of Washington is white. While 4.2% of the population is black and 9.2% of the population is Asian. The conclusion of this information is there exists the possibility for disparity in any statistical analysis of such a heavily dominated demographic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup
3
# Deleting unnecessary columns.
covid_data = pd.read_csv("washington-history.csv")
covid_data.drop("totalTestsViralIncrease",axis=1,inplace=True)
covid_data.drop("totalTestsViral",axis=1,inplace=True)
covid_data.drop("totalTestsPeopleViralIncrease",axis=1,inplace=True)
covid_data.drop("totalTestsPeopleViral",axis=1,inplace=True)
covid_data.drop("totalTestsPeopleAntigen",axis=1,inplace=True)
covid_data.drop("totalTestsPeopleAntibody",axis=1,inplace=True)
covid_data.drop("totalTestsAntigen",axis=1,inplace=True)
covid_data.drop("totalTestsAntibody",axis=1,inplace=True)
covid_data.drop("totalTestResultsIncrease",axis=1,inplace=True)
covid_data.drop("totalTestResults",axis=1,inplace=True)
covid_data.drop("totalTestEncountersViralIncrease",axis=1,inplace=True)
covid_data.drop("totalTestEncountersViral",axis=1,inplace=True)
covid_data.drop("recovered",axis=1,inplace=True)
covid_data.drop("positiveTestsViral",axis=1,inplace=True)
covid_data.drop("positiveTestsPeopleAntigen",axis=1,inplace=True)
covid_data.drop("positiveTestsPeopleAntibody",axis=1,inplace=True)
covid_data.drop("positiveTestsAntigen",axis=1,inplace=True)
covid_data.drop("positiveTestsAntibody",axis=1,inplace=True)
covid_data.drop("positiveScore",axis=1,inplace=True)
covid_data.drop("positiveIncrease",axis=1,inplace=True)
covid_data.drop("positiveCasesViral",axis=1,inplace=True)
covid_data.drop("onVentilatorCurrently",axis=1,inplace=True)
covid_data.drop("onVentilatorCumulative",axis=1,inplace=True)
covid_data.drop("negativeTestsViral",axis=1,inplace=True)
covid_data.drop("negativeTestsPeopleAntibody",axis=1,inplace=True)
covid_data.drop("negativeTestsAntibody",axis=1,inplace=True)
covid_data.drop("negativeIncrease",axis=1,inplace=True)
covid_data.drop("negative",axis=1,inplace=True)
covid_data.drop("inIcuCurrently",axis=1,inplace=True)
covid_data.drop("inIcuCumulative",axis=1,inplace=True)
covid_data.drop("deathConfirmed",axis=1,inplace=True)
covid_data.drop("deathProbable",axis=1,inplace=True)
covid_data.drop("state",axis=1,inplace=True)
covid_data.drop("hospitalizedCumulative",axis=1,inplace=True)
covid_data.drop("hospitalizedIncrease",axis=1,inplace=True)
covid_data
# Out:
#            date   death  deathIncrease  hospitalized  hospitalizedCurrently  \
# 0    2021-03-07  5041.0              0       19599.0                  431.0
# 1    2021-03-06  5041.0              9       19556.0                  431.0
# 2    2021-03-05  5032.0             20       19500.0                  413.0
# 3    2021-03-04  5012.0             24       19466.0                  461.0
# 4    2021-03-03  4988.0             19       19433.0                  467.0
# ..          ...     ...            ...           ...                    ...
# 415  2020-01-17     NaN              0           NaN                    NaN
# 416  2020-01-16     NaN              0           NaN                    NaN
# 417  2020-01-15     NaN              0           NaN                    NaN
# 418  2020-01-14     NaN              0           NaN                    NaN
# 419  2020-01-13     NaN              0           NaN                    NaN
#
#      positive
# 0    344532.0
# 1    343868.0
# ...

# %%
# Deleting unnecessary rows.
# I'm only analyzing data in a 1 year time frame.
for x in range(372, len(covid_data)):
    covid_data.drop(x,axis=0,inplace=True)
for x in range(7):
    covid_data.drop(x,axis=0,inplace=True)
covid_data
# Out:
#            date   death  deathIncrease  hospitalized  hospitalizedCurrently  \
# 7    2021-02-28  4956.0              0       19319.0                  498.0
# 8    2021-02-27  4956.0             14       19275.0                  498.0
# 9    2021-02-26  4942.0             30       19224.0                  548.0
# 10   2021-02-25  4912.0             31       19211.0                  534.0
# 11   2021-02-24  4881.0             24       19160.0                  544.0
# ..          ...     ...            ...           ...                    ...
# 367  2020-03-05    20.0              4           NaN                    NaN
# 368  2020-03-04    16.0              2           NaN                    NaN
# 369  2020-03-03    14.0              3           NaN                    NaN
# 370  2020-03-02    11.0              3           NaN                    NaN
# 371  2020-03-01     8.0              3           NaN                    NaN
#
#      positive
# 7    339773.0
# 8    338822.0
# ...

# %%
mean_data = covid_data["deathIncrease"].mean()
print(mean_data)
# df = pd.DataFrame(covid_data)
# for x in range(len(df)):
#     df["perDay"] = 
newData = covid_data.reset_index()
newData.drop("index",axis=1,inplace=True)
newData
# Out:
# 13.564383561643835
#            date   death  deathIncrease  hospitalized  hospitalizedCurrently  \
# 0    2021-02-28  4956.0              0       19319.0                  498.0
# 1    2021-02-27  4956.0             14       19275.0                  498.0
# 2    2021-02-26  4942.0             30       19224.0                  548.0
# 3    2021-02-25  4912.0             31       19211.0                  534.0
# 4    2021-02-24  4881.0             24       19160.0                  544.0
# ..          ...     ...            ...           ...                    ...
# 360  2020-03-05    20.0              4           NaN                    NaN
# 361  2020-03-04    16.0              2           NaN                    NaN
# 362  2020-03-03    14.0              3           NaN                    NaN
# 363  2020-03-02    11.0              3           NaN                    NaN
# 364  2020-03-01     8.0              3           NaN                    NaN
#
#      positive
# 0    339773.0
# ...

# %%
# df = pd.DataFrame(covid_data)
# df.assign
newData.describe()
# Out:
#              death  deathIncrease  hospitalized  hospitalizedCurrently  \
# count   365.000000     365.000000    284.000000             331.000000
# mean   2014.139726      13.564384   9375.179577             612.456193
# std    1275.142241      21.252779   4892.086242             266.404557
# min       8.000000    -166.000000   3125.000000             263.000000
# 25%    1118.000000       3.000000   5545.000000             407.000000
# 50%    1905.000000       9.000000   7747.500000             518.000000
# 75%    2704.000000      19.000000  13316.000000             728.000000
# max    4956.000000     174.000000  19319.000000            1280.000000
#
#             positive
# count     365.000000
# mean   108949.463014
# std    104230.092570
# min        26.000000
# 25%     22711.000000
# 50%     76155.000000
# 75%    173561.000000
# max    339773.000000

# %%
# New column showing average deaths per day relative to average deaths
# per day for the full year
deathIncreaseAveragePerDay = []
for x in range(len(newData.index)):
    deathIncreaseAveragePerDay.append(newData.loc[x,"deathIncrease"] / mean_data)
newData['deathsPerAveragePerDay'] = deathIncreaseAveragePerDay
newData
plt.scatter(newData.index, newData.deathsPerAveragePerDay)

# %%
hospitalized_mean = newData["hospitalizedCurrently"].mean
deathHospitalizedAveragePerDay = []
for x in range(len(newData.index)):
    deathHospitalizedAveragePerDay.append(newData.loc[x,"deathIncrease"] / mean_data)
newData['hospitalizedAveragePerDay'] = deathHospitalizedAveragePerDay
newData
# Out:
#            date   death  deathIncrease  hospitalized  hospitalizedCurrently  \
# 0    2021-02-28  4956.0              0       19319.0                  498.0
# 1    2021-02-27  4956.0             14       19275.0                  498.0
# 2    2021-02-26  4942.0             30       19224.0                  548.0
# 3    2021-02-25  4912.0             31       19211.0                  534.0
# 4    2021-02-24  4881.0             24       19160.0                  544.0
# ..          ...     ...            ...           ...                    ...
# 360  2020-03-05    20.0              4           NaN                    NaN
# 361  2020-03-04    16.0              2           NaN                    NaN
# 362  2020-03-03    14.0              3           NaN                    NaN
# 363  2020-03-02    11.0              3           NaN                    NaN
# 364  2020-03-01     8.0              3           NaN                    NaN
#
# ...

# %%
url = "https://en.wikipedia.org/wiki/COVID-19_pandemic_in_Washington_(state)#March_1%E2%80%935"
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
title = soup.title
print(title)
# Out:
# <title>COVID-19 pandemic in Washington (state) - Wikipedia</title>

# %%
title = soup.title
print(title)
# Out:
# <title>COVID-19 pandemic in Washington (state) - Wikipedia</title>

# %%
text = soup.get_text()
print(text)
# Out:
# COVID-19 pandemic in Washington (state) - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# COVID-19 pandemic in Washington (state)
#
# From Wikipedia, the free encyclopedia
#
#
#
# Jump to navigation
# Jump to search
# Ongoing COVID-19 viral pandemic in Washington state, United States
#
#
# COVID-19 pandemic in WashingtonMap of the outbreak in Washington by confirmed new infections per 100,000 people over 14 days; (click to see date updated)
#   1,000+
#   500–1,000
#   200–500
#   100–200
#   50–100
#   20–50
#   10–20
#   0–10
#   No confirmed new cases or no/bad dataMap of the outbreak in Washington by confirmed total infections per 100,000 people (click on map for date of update)
#   10,000+
#   3,000–10,000
#   1,000–3,000
#   300–1,000
#   100–300
#   30–100
#   0–30
# ...

# %%
# addRow = newData
# addRow.newData.loc[[365]]
newData.dropna(subset = ["hospitalized"], inplace=True)
newCleanData = newData.reset_index()
newCleanData.drop("index",axis=1,inplace=True)
newCleanData
# Out:
#            date   death  deathIncrease  hospitalized  hospitalizedCurrently  \
# 0    2021-02-28  4956.0              0       19319.0                  498.0
# 1    2021-02-27  4956.0             14       19275.0                  498.0
# 2    2021-02-26  4942.0             30       19224.0                  548.0
# 3    2021-02-25  4912.0             31       19211.0                  534.0
# 4    2021-02-24  4881.0             24       19160.0                  544.0
# ..          ...     ...            ...           ...                    ...
# 279  2020-05-25  1061.0              6        3287.0                  536.0
# 280  2020-05-24  1055.0              5        3256.0                  560.0
# 281  2020-05-23  1050.0              6        3230.0                  553.0
# 282  2020-05-22  1044.0              7        3156.0                  572.0
# 283  2020-05-21  1037.0              6        3125.0                  518.0
#
# ...

# %%
hospitalized_column = newCleanData["hospitalizedCurrently"]
max_hospitalized = hospitalized_column.max()
print(max_hospitalized)
# Out:
# 1280.0
